# %% [markdown]
# count words

# %%
import re

str = "1-hello sasa, fddd"

print(len(re.findall(r'\b[A-Za-z]+\b', str)))
# Out:
# 3

# %% [markdown]
# count i to j in increment and j to k in decrement

# %%
i = 2
j = 3
k = 3
print((i + j) * (j - i + 1) // 2 + (k + j - 1) * (j - k) // 2)
# Out:
# 0
